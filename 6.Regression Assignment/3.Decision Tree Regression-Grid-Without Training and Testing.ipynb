# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error','poisson' ],
              'splitter': ['best','random',],
            'max_depth': [None, 5, 10, 20, 30],   # depth of tree
    'min_samples_split': [2, 5, 10],      # minimum samples to split a node
    'min_samples_leaf': [1, 2, 4, 8]}      # minimum samples at a leaf

             


grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
 
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [None, 5, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4, 8],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_depth': 5, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.028586      0.006419         0.009347        0.003983
# 1         0.017672      0.001817         0.014571        0.001837
# 2         0.023987      0.003874         0.010028        0.002925
# 3         0.010149      0.004809         0.008653        0.003183
# 4         0.008337      0.003836         0.004730        0.003177
# ..             ...           ...              ...             ...
# 475       0.014778      0.002496         0.007080        0.001682
# 476       0.017727      0.001201         0.005122        0.001299
# 477       0.012960      0.002191         0.004216        0.001928
# 478       0.017495      0.001665         0.007424        0.001866
# 479       0.011605      0.003151         0.005934        0.001212
#
#     param_criterion param_max_depth  param_min_samples_leaf  \
# 0     squared_error            None                       1
# 1     squared_error            None                       1
# 2     squared_error            None                       1
# 3     squared_error            None                       1
# 4     squared_error            None                       1
# ..              ...             ...                     ...
# 475         poisson              30                       8
# 476         poisson              30                       8
# 477         poisson              30                       8
# 478         poisson              30                       8
# 479         poisson              30                       8
#
#      param_min_samples_split param_splitter  \
# 0                          2           best
# 1                          2         random
# 2                          5           best
# 3                          5         random
# 4                         10           best
# ..                       ...            ...
# 475                        2         random
# 476                        5           best
# 477                        5         random
# 478                       10           best
# 479                       10         random
#
#                                                 params  split0_test_score  \
# 0    {'criterion': 'squared_error', 'max_depth': No...           0.726988
# 1    {'criterion': 'squared_error', 'max_depth': No...           0.735755
# 2    {'criterion': 'squared_error', 'max_depth': No...           0.743683
# 3    {'criterion': 'squared_error', 'max_depth': No...           0.748065
# 4    {'criterion': 'squared_error', 'max_depth': No...           0.831445
# ..                                                 ...                ...
# 475  {'criterion': 'poisson', 'max_depth': 30, 'min...           0.853308
# 476  {'criterion': 'poisson', 'max_depth': 30, 'min...           0.857545
# 477  {'criterion': 'poisson', 'max_depth': 30, 'min...           0.852694
# 478  {'criterion': 'poisson', 'max_depth': 30, 'min...           0.857545
# 479  {'criterion': 'poisson', 'max_depth': 30, 'min...           0.795551
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.605597           0.727804           0.702955
# 1             0.585939           0.727726           0.725326
# 2             0.698485           0.764956           0.744286
# 3             0.769133           0.806746           0.793369
# 4             0.728182           0.798664           0.779250
# ..                 ...                ...                ...
# 475           0.776337           0.848756           0.777339
# 476           0.775938           0.877816           0.815609
# 477           0.772163           0.827071           0.809734
# 478           0.775938           0.877816           0.815609
# 479           0.764422           0.798239           0.837638
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.689783         0.690625        0.044916              474
# 1             0.745578         0.704065        0.059487              466
# 2             0.753717         0.741025        0.022632              453
# 3             0.775980         0.778659        0.020195              407
# 4             0.788777         0.785264        0.033523              384
# ..                 ...              ...             ...              ...
# 475           0.822942         0.815736        0.033408              200
# 476           0.844480         0.834278        0.035477              107
# 477           0.858102         0.823953        0.031261              147
# 478           0.844480         0.834278        0.035477              107
# 479           0.822567         0.803683        0.025087              310
#
# [480 rows x 18 columns]

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 35
# BMI: 20
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19379.74315]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
